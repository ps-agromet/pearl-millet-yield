# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import scipy.stats as stats

# %%
import os

# %%
# repository root (notebooks live in <repo>/notebooks)
base_loc = os.path.abspath(os.path.join(os.getcwd(), '..'))
data=pd.read_excel(os.path.join(base_loc,'output','compiled data.xlsx'))

# %%
sns.boxplot(data=data,x='Planting Date',y='Yield (tonne/ha)')

# %%
tab_rf=pd.pivot_table(data, values='Rainfall', index='District', columns='Planting Date', aggfunc='mean')
tab_y=pd.pivot_table(data, values='Yield (tonne/ha)', index='District', columns='Planting Date', aggfunc='mean')

# %%
# tab.to_excel(os.path.join(base_loc,'output','compiled mean.xlsx'))

# %%
data.columns

# %%
df=data[[ 'Mint', 'Maxt','Yield (tonne/ha)','ET','Rainfall']]
df.corr()

# %%
x = data['Yield (tonne/ha)'] 
y = data['Rainfall']
rho, p_value = stats.spearmanr(x, y)

# %%
print("Spearman Rank Correlation:", rho)
print("P-value:", p_value)

# %%
# df.corr().to_excel(os.path.join(base_loc,'output','compiled correlation.xlsx'))
